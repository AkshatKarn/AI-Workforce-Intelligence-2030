# %% [markdown]
# # AI Workforce Intelligence 2030
#
# ## Phase 2: Data Audit & Profiling
#
# **Prepared By:** Akshat Karn
#
# **Objective:**
# To understand the dataset, assess its quality, identify potential issues, and prepare it for exploratory data analysis.

# %% [markdown]
# # Section-1
# Importing all the libraries i.e pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Section-2
#
# importing the datest to the colab enviroment from local space to here

# %%
df=pd.read_csv('/content/AI_Impact_on_Jobs_2030.csv')

# %% [markdown]
# # Section-3
# This section consist of inital inspection that whether the data is loaded correctly or not

# %%
df.head(5)
# Out:
#   Employee_ID              Job_Title    Industry Country Education_Level  \
# 0  AIJ-100000          Data Engineer  Healthcare   Japan             PhD
# 1  AIJ-100001     Healthcare Analyst      Retail      UK        Bachelor
# 2  AIJ-100002          HR Specialist   Education  Canada     High School
# 3  AIJ-100003  Cybersecurity Analyst  Government      UK        Bachelor
# 4  AIJ-100004     Healthcare Analyst   Education     UAE             PhD
#
#    Years_Experience  AI_Replacement_Risk  Future_Demand_Score  \
# 0                 1                 0.25                 0.78
# 1                24                 0.73                 0.33
# 2                21                 0.80                 0.69
# 3                 5                 0.29                 0.94
# 4                20                 0.11                 0.92
#
#   Remote_Work_Possibility  Average_Salary_USD  \
# 0                     Yes              207392
# 1                      No              140785
# ...

# %%
df.tail(5)
# Out:
#      Employee_ID        Job_Title    Industry    Country Education_Level  \
# 2995  AIJ-102995   Data Scientist   Education      India        Bachelor
# 2996  AIJ-102996    Data Engineer  Healthcare        UAE             PhD
# 2997  AIJ-102997  DevOps Engineer      Energy   Pakistan     High School
# 2998  AIJ-102998   Data Scientist  Government  Australia        Bachelor
# 2999  AIJ-102999    HR Specialist      Retail    Germany          Master
#
#       Years_Experience  AI_Replacement_Risk  Future_Demand_Score  \
# 2995                 0                 0.62                 0.27
# 2996                 4                 0.52                 0.57
# 2997                 7                 0.72                 0.70
# 2998                19                 0.82                 0.76
# 2999                 9                 0.68                 0.44
#
#      Remote_Work_Possibility  Average_Salary_USD  \
# 2995                  Hybrid              202565
# ...

# %%
df.sample(5, random_state=42)
# Out:
#      Employee_ID                  Job_Title       Industry  Country  \
# 1801  AIJ-101801  Machine Learning Engineer  Manufacturing   Canada
# 1190  AIJ-101190          Robotics Engineer        Finance      USA
# 1817  AIJ-101817          Financial Analyst      Education      USA
# 251   AIJ-100251            Cloud Architect     Technology  Germany
# 2505  AIJ-102505            Cloud Architect      Education      UAE
#
#      Education_Level  Years_Experience  AI_Replacement_Risk  \
# 1801          Master                 6                 0.71
# 1190             PhD                13                 0.20
# 1817     High School                14                 0.74
# 251         Bachelor                 9                 0.23
# 2505     High School                11                 0.87
#
#       Future_Demand_Score Remote_Work_Possibility  Average_Salary_USD  \
# 1801                 0.95                  Hybrid               31850
# ...

# %% [markdown]
# #Section-4
# This section gives the very basic info about the dataset i.e no. coulumns rows name of columns and info regarding data types.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 3000
# Columns: 20

# %%
df.columns.tolist()
# Out:
# ['Employee_ID',
#  'Job_Title',
#  'Industry',
#  'Country',
#  'Education_Level',
#  'Years_Experience',
#  'AI_Replacement_Risk',
#  'Future_Demand_Score',
#  'Remote_Work_Possibility',
#  'Average_Salary_USD',
#  'Required_Skills',
#  'Automation_Level',
#  'Job_Growth_2030',
#  'Work_Hours_Per_Week',
#  'Company_Size',
#  'AI_Tool_Usage',
#  'Performance_Score',
#  'Upskilling_Needed',
#  'Job_Satisfaction',
#  'Hiring_Trend_2026']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee_ID              3000 non-null   object
#  1   Job_Title                3000 non-null   object
#  2   Industry                 3000 non-null   object
#  3   Country                  3000 non-null   object
#  4   Education_Level          3000 non-null   object
#  5   Years_Experience         3000 non-null   int64
#  6   AI_Replacement_Risk      3000 non-null   float64
#  7   Future_Demand_Score      3000 non-null   float64
#  8   Remote_Work_Possibility  3000 non-null   object
#  9   Average_Salary_USD       3000 non-null   int64
#  10  Required_Skills          3000 non-null   object
#  11  Automation_Level         3000 non-null   object
#  12  Job_Growth_2030          3000 non-null   int64
#  13  Work_Hours_Per_Week      3000 non-null   int64
# ...

# %% [markdown]
# # Section-5
# This Section tells me about the unique values duplicate values and null values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Employee_ID                0
# Job_Title                  0
# Industry                   0
# Country                    0
# Education_Level            0
# Years_Experience           0
# AI_Replacement_Risk        0
# Future_Demand_Score        0
# Remote_Work_Possibility    0
# Average_Salary_USD         0
# Required_Skills            0
# Automation_Level           0
# Job_Growth_2030            0
# Work_Hours_Per_Week        0
# Company_Size               0
# AI_Tool_Usage              0
# Performance_Score          0
# Upskilling_Needed          0
# Job_Satisfaction           0
# Hiring_Trend_2026          0
# dtype: int64

# %%
df.nunique()
# Out:
# Employee_ID                3000
# Job_Title                    20
# Industry                     10
# Country                      10
# Education_Level               4
# Years_Experience             26
# AI_Replacement_Risk          91
# Future_Demand_Score          80
# Remote_Work_Possibility       3
# Average_Salary_USD         2970
# Required_Skills            2937
# Automation_Level              3
# Job_Growth_2030              56
# Work_Hours_Per_Week          31
# Company_Size                  3
# AI_Tool_Usage                 3
# Performance_Score           301
# Upskilling_Needed             2
# Job_Satisfaction            401
# Hiring_Trend_2026             3
# dtype: int64

# %% [markdown]
# #Section-6
# This section Summarizes the data and provide the summary statistics of the Data.

# %%
df.describe()
# Out:
#        Years_Experience  AI_Replacement_Risk  Future_Demand_Score  \
# count       3000.000000          3000.000000          3000.000000
# mean          12.383000             0.502910             0.601203
# std            7.528958             0.261293             0.226674
# min            0.000000             0.050000             0.200000
# 25%            6.000000             0.280000             0.420000
# 50%           12.000000             0.500000             0.600000
# 75%           19.000000             0.730000             0.800000
# max           25.000000             0.950000             0.990000
#
#        Average_Salary_USD  Job_Growth_2030  Work_Hours_Per_Week  \
# count         3000.000000      3000.000000          3000.000000
# mean        126641.746667        17.238333            44.773333
# std          55405.053057        16.230322             8.926469
# min          30221.000000       -10.000000            30.000000
# ...

# %%
df.describe(include="object")
# Out:
#        Employee_ID           Job_Title Industry Country Education_Level  \
# count         3000                3000     3000    3000            3000
# unique        3000                  20       10      10               4
# top     AIJ-102999  Software Developer   Energy     UAE        Bachelor
# freq             1                 164      335     347             782
#
#        Remote_Work_Possibility                          Required_Skills  \
# count                     3000                                     3000
# unique                       3                                     2937
# top                     Hybrid  Cloud Computing, Kubernetes, Leadership
# freq                      1011                                        3
#
#        Automation_Level Company_Size AI_Tool_Usage Upskilling_Needed  \
# count              3000         3000          3000              3000
# unique                3            3             3                 2
# ...
